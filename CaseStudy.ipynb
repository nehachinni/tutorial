# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\chinn\OneDrive\Desktop\Jupyter projects\diabetes .csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['Age'],df['Glucose'])
plt.xlabel("Age")
plt.ylabel("Survived")
plt.show()

# %%
def bar_plot(variable):
    var=df[variable]
    varValue=var.value_counts()
    plt.figure(figsize=(9,3))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,varValue))

# %%
columns_plot=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
for i in columns_plot:
    bar_plot(i)
# Out:
# Pregnancies:
#  Pregnancies
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 17      1
# 15      1
# Name: count, dtype: int64
# Glucose:
#  Glucose
# 99     17
# 100    17
# 111    14
# 125    14
# 129    14
#        ..
# 56      1
# 169     1
# 149     1
# 65      1
# 190     1
# Name: count, Length: 136, dtype: int64
# BloodPressure:
#  BloodPressure
# 70     57
# 74     52
# 78     45
# 68     45
# 72     44
# 64     43
# 80     40
# 76     39
# 60     37
# 0      35
# 62     34
# 66     30
# 82     30
# 88     25
# 84     23
# 90     22
# 86     21
# 58     21
# 50     13
# 56     12
# 54     11
# 52     11
# 92      8
# 75      8
# 65      7
# 85      6
# 94      6
# 48      5
# 44      4
# 96      4
# 110     3
# 106     3
# 100     3
# 98      3
# 30      2
# 46      2
# 55      2
# 104     2
# 108     2
# 40      1
# 122     1
# 95      1
# ...

# %%
plt.hist(df['Pregnancies'])
plt.show()

# %%
plt.hist(df['Glucose'])
plt.show()

# %%
plt.hist(df['BloodPressure'])
plt.show()

# %%
plt.hist(df['SkinThickness'])
plt.show()

# %%
plt.hist(df['Insulin'])
plt.show()

# %%
plt.hist(df[ 'BMI'])
plt.show()

# %%
plt.hist(df['DiabetesPedigreeFunction'])
plt.show()

# %%
plt.hist(df['Age'])
plt.show()

# %%
plt.hist(df['Outcome'])
plt.show()

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df[[ 'Pregnancies', 'Glucose']].groupby(['Pregnancies'],as_index=False).mean().sort_values(by='Glucose',ascending=False)
# Out:
#     Pregnancies     Glucose
# 16           17  163.000000
# 14           14  137.500000
# 7             7  136.444444
# 15           15  136.000000
# 8             8  131.736842
# 9             9  131.392857
# 11           11  126.454545
# 13           13  125.500000
# 4             4  125.117647
# 3             3  123.586667
# 0             0  123.000000
# 10           10  120.916667
# 6             6  120.800000
# 5             5  118.859649
# 12           12  113.555556
# 1             1  112.748148
# 2             2  110.796117

# %%
df[['BloodPressure',  'Age']].groupby([ 'BloodPressure'],as_index=False).mean().sort_values(by= 'Age',ascending=False)
# Out:
#     BloodPressure        Age
# 36             95  60.000000
# 15             61  55.000000
# 43            108  51.000000
# 42            106  47.000000
# 41            104  46.500000
# 40            102  45.000000
# 34             92  44.625000
# 45            114  44.000000
# 35             94  39.833333
# 28             82  39.466667
# 26             78  39.088889
# 44            110  39.000000
# 29             84  38.565217
# 33             90  38.136364
# 22             72  37.295455
# 30             85  36.833333
# 27             80  35.650000
# 23             74  35.500000
# 32             88  35.440000
# 25             76  35.410256
# 31             86  34.190476
# 39            100  34.000000
# 24             75  33.250000
# 4              40  33.000000
# 21             70  31.982456
# 38             98  31.666667
# 20             68  31.555556
# 37             96  31.500000
# 11             55  31.500000
# 0               0  30.714286
# 19             66  29.900000
# ...

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
sns.boxplot(x='Pregnancies',
y='Glucose',data=df)
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Glucose'>

# %%
sns.boxplot(x='BloodPressure',
y='Age',data=df)
# Out:
# <Axes: xlabel='BloodPressure', ylabel='Age'>

# %%
sns.boxplot(x='Insulin',
y= 'Age',data=df)
# Out:
# <Axes: xlabel='Insulin', ylabel='Age'>

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
sns.boxplot(df['Pregnancies'])
# Out:
# <Axes: ylabel='Pregnancies'>

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
sns.boxplot(df['Glucose'])
# Out:
# <Axes: ylabel='Glucose'>

# %%
sns.boxplot(df[ 'BloodPressure'])
# Out:
# <Axes: ylabel='BloodPressure'>

# %%
sns.boxplot(df['SkinThickness'])
# Out:
# <Axes: ylabel='SkinThickness'>

# %%
sns.boxplot(df['Insulin'])
# Out:
# <Axes: ylabel='Insulin'>

# %%
sns.boxplot(df['BMI'])
# Out:
# <Axes: ylabel='BMI'>

# %%
sns.boxplot(df['DiabetesPedigreeFunction'])
# Out:
# <Axes: ylabel='DiabetesPedigreeFunction'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(df['Outcome'])
# Out:
# <Axes: ylabel='Outcome'>

# %%
df.drop(labels=['Pregnancies', 'Glucose', 'BloodPressure', 'Insulin',
       'BMI'],axis=1)
# Out:
#      SkinThickness  DiabetesPedigreeFunction  Age  Outcome
# 0               35                     0.627   50        1
# 1               29                     0.351   31        0
# 2                0                     0.672   32        1
# 3               23                     0.167   21        0
# 4               35                     2.288   33        1
# ..             ...                       ...  ...      ...
# 763             48                     0.171   63        0
# 764             27                     0.340   27        0
# 765             23                     0.245   30        0
# 766              0                     0.349   47        1
# 767             31                     0.315   23        0
#
# [768 rows x 4 columns]

# %%
df.drop(labels=['Pregnancies', 'Glucose', 'BloodPressure', 'Insulin',
       'BMI'],axis=1,inplace=True)

# %%
df.head(3)
# Out:
#    SkinThickness  DiabetesPedigreeFunction  Age  Outcome
# 0             35                     0.627   50        1
# 1             29                     0.351   31        0
# 2              0                     0.672   32        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SkinThickness             768 non-null    int64
#  1   DiabetesPedigreeFunction  768 non-null    float64
#  2   Age                       768 non-null    int64
#  3   Outcome                   768 non-null    int64
# dtypes: float64(1), int64(3)
# memory usage: 24.1 KB

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(),annot=True,fmt='.2f')
plt.show()
